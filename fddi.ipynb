# %%
# !git clone https://github.com/YifanDengWHU/DDIMDL.git
# Out:
# Cloning into 'DDIMDL'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 85 (delta 35), reused 22 (delta 22), pack-reused 47
# Unpacking objects: 100% (85/85), 4.84 MiB | 3.79 MiB/s, done.

# %%
# !pip install stanfordnlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import stanfordnlp
stanfordnlp.download('en')
# Out:
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
# y
#
# Default download directory: /root/stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
#
#
# ...
# Download location: /root/stanfordnlp_resources/en_ewt_models.zip
# 100%|██████████| 235M/235M [00:40<00:00, 5.85MB/s]
# Download complete.  Models saved to: /root/stanfordnlp_resources/en_ewt_models.zip
# Extracting models file for: en_ewt
# Cleaning up...Done.

# %%
# %cd DDIMDL/requirement
# Out:
# [Errno 2] No such file or directory: 'DDIMDL/requirement'
# /content

# %%
# !pip install requirement.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement requirement.txt (from versions: none)
# ERROR: No matching distribution found for requirement.txt

# %%
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# DDIMDL/  sample_data/

# %%
# %cd DDIMDL/
# Out:
# /content/DDIMDL

# %%
# !pip install git+https://github.com/pyqtgraph/pyqtgraph.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/pyqtgraph/pyqtgraph.git to /tmp/pip-req-build-82lxw4x8
#   Running command git clone --filter=blob:none --quiet https://github.com/pyqtgraph/pyqtgraph.git /tmp/pip-req-build-82lxw4x8
#   Resolved https://github.com/pyqtgraph/pyqtgraph.git to commit 3f5ba98530b1b122a49b85d75e1786c888b14d08
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyqtgraph: filename=pyqtgraph-0.13.4.dev0-py3-none-any.whl size=961075 sha256=d2bdc7a452a75beaa214a53f5081123e13ee9bc4c8a0d27c586c66c75a14fa30
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vdmy6w1q/wheels/10/9e/ea/a8334ca27a199a42f948f2a573906ff7fd754b060b5779b6cc
# Successfully built pyqtgraph
# ...

# %%
# !pip3 uninstall PyCrypto
# !pip3 install -U PyCryptodome
# Out:
# WARNING: Skipping PyCrypto as it is not installed.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.9 MB/s eta 0:00:00
# ...

# %%
# !pip3 install "scikit_learn==0.22.2.post1"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 32.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit_learn: filename=scikit_learn-0.22.2.post1-cp310-cp310-linux_x86_64.whl size=23201305 sha256=d88a790f1a1970e351e97ab841cf06cc520d19cb3a7249c50931293138688bcf
#   Stored in directory: /root/.cache/pip/wheels/ce/2c/b8/7c122186e1eaa3d04170e9eb4ad410115e7e593a57d2366e4c
# Successfully built scikit_learn
# ...
#   Attempting uninstall: scikit_learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install nlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 20.3 MB/s eta 0:00:00
# ...

# %%
import time
# !python DDIMDL.py -f smile target enzyme -c DDIMDL -p read
# Out:
# 2023-05-07 03:17:35.069784: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 03:17:37.143445: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
# {'featureList': ['smile', 'target', 'enzyme'], 'classifier': ['DDIMDL'], 'NLPProcess': 'read'}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    572 non-null    int64
#  1   id       572 non-null    object
#  2   target   572 non-null    object
#  3   enzyme   572 non-null    object
#  4   pathway  572 non-null    object
#  5   smile    572 non-null    object
# ...

# %%
# !python DRKG_drugg_spider.py
# Out:
# Streaming output truncated to the last 5000 lines.
# DB07125
# DB07126
# DB07127
# DB07128
# DB07129
# DB07130
# DB07131
# DB07132
# DB07133
# DB07134
# DB07135
# DB07136
# DB07137
# DB07138
# DB07139
# DB07140
# DB07141
# DB07142
# DB07143
# DB07144
# DB07145
# DB07146
# DB07147
# DB07148
# DB07149
# DB07150
# DB07151
# DB07152
# DB07153
# DB07154
# DB07155
# DB07156
# DB07157
# DB07158
# DB07159
# DB07160
# DB07161
# DB07162
# DB07163
# DB07164
# DB07165
# DB07167
# DB07168
# DB07169
# DB07170
# DB07171
# DB07172
# DB07173
# DB07174
# DB07175
# DB07176
# DB07177
# DB07178
# DB07179
# DB07180
# DB07181
# DB07182
# DB07183
# DB07184
# DB07185
# DB07186
# DB07187
# DB07188
# DB07189
# DB07190
# DB07192
# DB07193
# DB07194
# DB07195
# DB07196
# DB07197
# DB07198
# DB07199
# DB07200
# DB07201
# DB07202
# DB07203
# DB07204
# DB07205
# DB07206
# DB07207
# DB07208
# DB07209
# DB07210
# DB07211
# DB07212
# DB07213
# DB07215
# DB07216
# DB07217
# DB07218
# DB07219
# DB07220
# DB07221
# ...

# %%
# !python NLPProcess.py
